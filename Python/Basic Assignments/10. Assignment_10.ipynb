# %% [markdown]
# #### Ques 1. How do you distinguish between shutil.copy() and shutil.copytree()?

# %% [markdown]
# Answer:
#
# shutil.copy() method is used to copy the contents of a file from one file to another file/folder, it primary takes two arguments src, dest, src represents the file to be copied where as destination refers to the file/folder to where the src data should be copied, if dest is a folder name the src with exact name will be copied to the dest folder, if its a file then the contents of src will be copied to dest where dest retains it name.
#
# shutil.copytree() function is used to copy the entire contents of a folder to other folder. It also takes two arguments src & dest, it copies all the content recursively and stores it in dest. The important catch here is dest must not exist prior to this and it will be created during the copy operation. Permissions and times of directories are copied with shutil.copystat() and individual files are copied using shutil.copy2() by default which can be modified using copy_function attribute.

# %% [markdown]
# #### Ques 2. What function is used to rename files??

# %% [markdown]
# Answer:
#
# os.rename() function is used to rename files or directories using a python program, this function takes two arguments src and dest, src represents the name file/directory which we want to rename, whereas dest represents the new name of the file/directory.

# %% [markdown]
# #### Ques 3. What is the difference between the delete functions in the send2trash and shutil modules?

# %% [markdown]
# Answer:
#
# Shutil module provides a funciton called as shutil.rmtree() which deletes a directory and all its contents. The other functions with similar functionality are os.remove() -> removes a file, os.rmdir() removes a empty directory. The problem with these functions is once a file is deleted. It will be lost permanently, if a file is deleted accidentally using these methods there is no way we can recover the deleted file.
#
# Where as send2trash module provides a function called send2trash.send2trash() to delete a file/directory. these methods moves the files/directories to trash folder instead of permanently deleting them. Hence if a file/folder is deleted accidentally it can be still recovered from trash folder, if is deleted using the send2trash.send2trash() function. send2trash is not included with python standard libary like os & shutil modules. It needs to be installed explicitly using the command !pip install send2trash.

# %% [markdown]
# #### Ques 4. ZipFile objects have a close() method just like File objects’ close() method. What ZipFile method is equivalent to File objects’ open() method?

# %% [markdown]
# Answer:
#
# ZipFile Module provides a method called as zipfile.ZipFile() to read and write to zipFiles. It takes arugments lile filename and mode etc zipfile.ZipFile('filename', mode = 'r').

# %% [markdown]
# #### Ques 5. Create a programme that searches a folder tree for files with a certain file extension (such as .pdf or .jpg). Copy these files from whatever location they are in to a new folder.

# %%
#Answer:

import os
import shutil

def search_and_copy(source,destination,extensions):
    source = os.path.abspath(source)
    destination = os.path.abspath(destination)
    for foldername, subfolder, filenames in os.walk(source):
        print(f'Folder Name ➞ {foldername}',end='\n\n')
        print(f'Sub Folders ➞ {subfolder}',end='\n\n')
        print(f'Files ➞ {filenames}',end='\n\n')
        for filename in filenames:
            fileName,extension = os.path.splitext(filename)
            if extension in extensions:
                targetFile = foldername+os.path.sep+fileName+extension
                shutil.copy(targetFile, destination)
        print(f'Files copied successfully from {source} to {destination}')
    
extensions = ['.pdf','.jpg','.ipynb']
source = 'D:/sameer'
destination = 'D:/apps'
search_and_copy(source, destination, extensions)
# Out:
# Folder Name ➞ D:\sameer
#
# Sub Folders ➞ ['certifications', 'college', 'data', 'project', 'sam']
#
# Files ➞ ['Cover Letter Sameer Data Scientist.pdf', 'Sameer Singh – Data Scientist.pdf']
#
# Files copied successfully from D:\sameer to D:\apps
# Folder Name ➞ D:\sameer\certifications
#
# Sub Folders ➞ []
#
# Files ➞ ['Monolithic and Microservices architecture - Scaler.png', 'Multiprocessing and Multithreading in python.png']
#
# Files copied successfully from D:\sameer to D:\apps
# Folder Name ➞ D:\sameer\college
#
# Sub Folders ➞ ['Eshank sir assignments and projects', 'ppts', 'r assignments', 'r files']
#
# Files ➞ []
#
# Files copied successfully from D:\sameer to D:\apps
# Folder Name ➞ D:\sameer\college\Eshank sir assignments and projects
#
# Sub Folders ➞ []
#
# Files ➞ ['Amazon Sales Analysis Project.docx', 'Amazon Sales Analysis Project.pdf']
#
# Files copied successfully from D:\sameer to D:\apps
# Folder Name ➞ D:\sameer\college\ppts
#
# Sub Folders ➞ ['sem 4']
#
# Files ➞ ['NLP_SEM3.pptx', 'Planning and Learning with Tabular methods.pptx', 'PPT_NN_SEM3.pptx', 'R programming sem 3 practical.pptx', 'sas sem 3.pptx']
#
# Files copied successfully from D:\sameer to D:\apps
# Folder Name ➞ D:\sameer\college\ppts\sem 4
#
# Sub Folders ➞ []
#
# Files ➞ ['Advance machine learning.pptx', 'Business analytics.pptx', 'Image and video analytics.pptx', 'Text Analytics.pptx']
#
# Files copied successfully from D:\sameer to D:\apps
# Folder Name ➞ D:\sameer\college\r assignments
#
# Sub Folders ➞ []
#
# Files ➞ ['r assignment part 1.R', 'r assignment part 2.R', 'r assignment part 3.R', 'r plot 1.png', 'r plot 2.png', 'r plot 3.png', 'r plot 4.png', 'r plot 5.png']
#
# Files copied successfully from D:\sameer to D:\apps
# Folder Name ➞ D:\sameer\college\r files
#
# Sub Folders ➞ []
#
# Files ➞ ['apply functions in r.R', 'covid_project.R', 'data handling in r.R', 'data manipulation in r.R', 'normal apply function.R']
#
# Files copied successfully from D:\sameer to D:\apps
# Folder Name ➞ D:\sameer\data
#
# Sub Folders ➞ ['aws_live_project']
#
# Files ➞ ['Admission_Predict.csv', 'Admission_Prediction.csv', 'Admission_Predict_Ver1.1.csv', 'Airlines dataset.xlsx', 'Airplane_Crashes_and_Fatalities_Since_1908.csv', 'Bengaluru_House_Data.csv', 'car_data.csv', 'covid_19_data.xlsx', 'Departments.csv', 'fake_real_news.csv', 'household_power_consumption.txt', 'Indian States.xlsx', 'kc_house_Data.csv', 'Locations.csv', 'LungCapData2.xlsx.csv', 'netflix_titles.xlsx', 'news.csv', 'porto-seguro-safe-driver-prediction.zip', 'sample_-_superstore (1).xls', 'sample_-_superstore.xls', 'Spicejet_data.csv', 'StockExample.csv', 'test.csv', 'test_excel1.xlsx', 'test_excel2.xlsx', 'train.csv', 'UT Mart csv file.csv', 'WHO-COVID-19-global-data.csv', 'winequality-red.csv', 'zomato.csv']
#
# Files copied successfully from D:\sameer to D:\apps
# Folder Name ➞ D:\sameer\data\aws_live_project
#
# Sub Folders ➞ ['.ipynb_checkpoints', 'amazonproject', 'Sales_Data']
#
# Files ➞ ['LINUX PART-1.pptx', 'LIVE PROJECT PANDAS (1).ipynb', 'LIVE PROJECT PANDAS .ipynb', 'PANDAS LIVE PROJECT.ipynb', 'Sales_Data.rar', 'Sales_Data.zip', 'SQL INTEGRATION WITH DATA CREATION.ipynb', 'Untitled.ipynb', 'Untitled1.ipynb', 'Untitled2.ipynb', '~$LINUX PART-1.pptx']
#
# Files copied successfully from D:\sameer to D:\apps
# Folder Name ➞ D:\sameer\data\aws_live_project\.ipynb_checkpoints
#
# Sub Folders ➞ []
#
# Files ➞ ['LIVE PROJECT PANDAS (1)-checkpoint.ipynb', 'LIVE PROJECT PANDAS -checkpoint.ipynb', 'PANDAS LIVE PROJECT-checkpoint.ipynb', 'SQL INTEGRATION WITH DATA CREATION-checkpoint.ipynb', 'Untitled-checkpoint.ipynb', 'Untitled1-checkpoint.ipynb', 'Untitled2-checkpoint.ipynb']
#
# Files copied successfully from D:\sameer to D:\apps
# Folder Name ➞ D:\sameer\data\aws_live_project\amazonproject
#
# Sub Folders ➞ []
#
# Files ➞ ['AMAZON_PROJECT.xlsx', 'pipeline.py', 'visaulisation month vs sales.png', 'visualisation city vs sales vs quantity ordered.png', 'visualisation hour vs sales vs quantity ordered.png', 'visualisation month vs sales vs quantity ordered.png', 'visualisation top5 product as per city  vs sales vs quantity ordered.png']
#
# Files copied successfully from D:\sameer to D:\apps
# Folder Name ➞ D:\sameer\data\aws_live_project\Sales_Data
#
# Sub Folders ➞ []
#
# Files ➞ ['Sales_April_2019.csv', 'Sales_August_2019.csv', 'Sales_December_2019.csv', 'Sales_February_2019.csv', 'Sales_January_2019.csv', 'Sales_July_2019.csv', 'Sales_June_2019.csv', 'Sales_March_2019.csv', 'Sales_May_2019.csv', 'Sales_November_2019.csv', 'Sales_October_2019.csv', 'Sales_September_2019.csv']
#
# Files copied successfully from D:\sameer to D:\apps
# Folder Name ➞ D:\sameer\project
#
# Sub Folders ➞ ['flask Eshank sir', 'Flipkart Webscraping', 'pixel_api']
#
# Files ➞ []
#
# Files copied successfully from D:\sameer to D:\apps
# Folder Name ➞ D:\sameer\project\flask Eshank sir
#
# Sub Folders ➞ ['Static', 'templates']
#
# Files ➞ ['main_flask.py']
#
# Files copied successfully from D:\sameer to D:\apps
# Folder Name ➞ D:\sameer\project\flask Eshank sir\Static
#
# Sub Folders ➞ []
#
# Files ➞ ['index.css']
#
# Files copied successfully from D:\sameer to D:\apps
# Folder Name ➞ D:\sameer\project\flask Eshank sir\templates
#
# Sub Folders ➞ []
#
# Files ➞ ['index.html', 'trail_file.html']
#
# Files copied successfully from D:\sameer to D:\apps
# Folder Name ➞ D:\sameer\project\Flipkart Webscraping
#
# Sub Folders ➞ ['.vscode', 'static', 'templates']
#
# Files ➞ ['app.py']
#
# Files copied successfully from D:\sameer to D:\apps
# Folder Name ➞ D:\sameer\project\Flipkart Webscraping\.vscode
#
# Sub Folders ➞ []
#
# Files ➞ ['settings.json']
#
# Files copied successfully from D:\sameer to D:\apps
# Folder Name ➞ D:\sameer\project\Flipkart Webscraping\static
#
# Sub Folders ➞ []
#
# Files ➞ ['home_css.css']
#
# Files copied successfully from D:\sameer to D:\apps
# Folder Name ➞ D:\sameer\project\Flipkart Webscraping\templates
#
# Sub Folders ➞ []
#
# Files ➞ ['about.html', 'Home.html', 'results.html', 'sentiment.html']
#
# Files copied successfully from D:\sameer to D:\apps
# Folder Name ➞ D:\sameer\project\pixel_api
#
# Sub Folders ➞ ['static', 'templates']
#
# Files ➞ ['pixel_api.py', 'requirements.txt']
#
# Files copied successfully from D:\sameer to D:\apps
# Folder Name ➞ D:\sameer\project\pixel_api\static
#
# Sub Folders ➞ []
#
# Files ➞ []
#
# Files copied successfully from D:\sameer to D:\apps
# Folder Name ➞ D:\sameer\project\pixel_api\templates
#
# Sub Folders ➞ []
#
# Files ➞ ['index.html']
#
# Files copied successfully from D:\sameer to D:\apps
# Folder Name ➞ D:\sameer\sam
#
# Sub Folders ➞ ['Documents']
#
# Files ➞ []
#
# Files copied successfully from D:\sameer to D:\apps
# Folder Name ➞ D:\sameer\sam\Documents
#
# Sub Folders ➞ []
#
# Files ➞ ['10th marksheet.jpg', '12th result sameer.pdf', 'aadhar sameer.jpeg', 'class 12 result.jpg', 'OBC certificate.jpg', 'passport size photo.jpg', 'profile box.jpg', 'profile.jpg', 'Resume YouTube marketer (PDF).pdf', 'Resume YouTube marketer.docx', 'signature.jpg']
#
# Files copied successfully from D:\sameer to D:\apps
